# %% [markdown]
# <a href="https://colab.research.google.com/github/foroughmand/quran-embedding/blob/main/quran_embedding_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://figshare.com/ndownloader/files/51376832 -O quran_embedding.csv
# Out:
# --2024-12-25 20:34:44--  https://figshare.com/ndownloader/files/51376832
# Resolving figshare.com (figshare.com)... 52.18.150.128, 18.202.168.57, 2a05:d018:1f4:d003:15ed:5b5f:136e:b537, ...
# Connecting to figshare.com (figshare.com)|52.18.150.128|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://s3-eu-west-1.amazonaws.com/pfigshare-u-files/51376832/pourmand1376arabicqurannahjsahifequran_embeddingsw5.csv?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAIYCQYOYV5JSSROOA/20241225/eu-west-1/s3/aws4_request&X-Amz-Date=20241225T203444Z&X-Amz-Expires=10&X-Amz-SignedHeaders=host&X-Amz-Signature=4f2a71a4dafa568c52d43e6011e88fca1b2231214a3fef298eee9290d43d70d2 [following]
# ...

# %%
import pandas as pd
qe = pd.read_csv("quran_embedding.csv")

# %%
qe[]
# Out:
#       Unnamed: 0  sure     sure_name  aye_start  aye_end  len  window_len  \
# 0              0     0  1_Al-Faatiha          1        1    1           5
# 1              1     0  1_Al-Faatiha          1        4    4           5
# 2              2     0  1_Al-Faatiha          3        7    5           5
# 3              3     0  1_Al-Faatiha          4        7    4           5
# 4              4     0  1_Al-Faatiha          1        3    3           5
# ...          ...   ...           ...        ...      ...  ...         ...
# 6678        6678   113   114_An-Naas          3        6    4           5
# 6679        6679   113   114_An-Naas          6        6    1           5
# 6680        6680   113   114_An-Naas          1        5    5           5
# 6681        6681   113   114_An-Naas          4        6    3           5
# 6682        6682   113   114_An-Naas          2        6    5           5
#
#                                                   verse  \
# ...
